# %%
import pandas as pd
import numpy as np
import os 
from pathlib import Path

# %%
#Loading the data into the data frame.

path = 'airbnb.csv'
#print(open(path).read())
df = pd.read_csv(path, on_bad_lines='skip')
 
df.head(5)
# Out:
#     Host Id  Host Since                                Name Neighbourhood   \
# 0   5162530         NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899         NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626         NaN                Sunny Room in Harlem      Manhattan
# 3       500  26/06/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  26/06/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
#    Number of Records  Number Of Reviews Price  Review Scores Rating
# 0                  1                  0   145                   NaN
# 1                  1                  1    37                   NaN
# 2                  1                  1    28                   NaN
# 3                  1                  0   199                   NaN
# 4                  1                 39   549                  96.0

# %%
#Checking the types of data
df.dtypes
# Out:
# Host Id                         int64
# Host Since                     object
# Name                           object
# Neighbourhood                  object
# Property Type                  object
# Review Scores Rating (bin)    float64
# Room Type                      object
# Zipcode                       float64
# Beds                          float64
# Number of Records               int64
# Number Of Reviews               int64
# Price                          object
# Review Scores Rating          float64
# dtype: object

# %%
#Dropping the duplicate rows
df.shape
# Out:
# (30473, 13)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (17, 13)

# %%
duplicate_rows_df
# Out:
#         Host Id  Host Since                                 Name  \
# 31         3867  29/10/2008  Share a bedroom in a huge Apartment
# 6313    2053408  02/04/2012  Semi-Private Room near Central Park
# 8571    3240890  13/08/2012        $60 Cozy fully furnished room
# 21337  18163232  15/07/2014     Your room in sun drenched duplex
# 21702  19068554  28/07/2014     Charming West Village Apartment!
# 22557  20780082  31/08/2014                  Wen Xin Hostel (35)
# 22558  20780082  31/08/2014                  Wen Xin Hostel (35)
# 22568  20780082  31/08/2014                  Wen Xin Hostel (80)
# 23763  22964323  25/10/2014     Bushwick 1 or 2 Rooms available.
# 23857  23120620  29/10/2014   Beachfront Queen Room at townhouse
# 23858  23120620  29/10/2014   Beachfront Queen Room at townhouse
# 28569  35968845  16/06/2015      Private room. Amazing location!
# 29206  37993298  09/07/2015                 The Brooklyn Riviera
# 29207  37993298  09/07/2015                 The Brooklyn Riviera
# 29209  37993298  09/07/2015                 The Brooklyn Riviera
# 29710  39808613  28/07/2015  LARGE ROOM! 20MIN. FROM TIME SQUARE
# 29727  39808613  28/07/2015          ROOM SHARE NEAR TIME SQUARE
#
#       Neighbourhood  Property Type  Review Scores Rating (bin)  \
# 31         Manhattan     Apartment                         NaN
# 6313       Manhattan     Apartment                         NaN
# 8571        Brooklyn     Apartment                         NaN
# 21337       Brooklyn     Apartment                       100.0
# 21702      Manhattan     Apartment                         NaN
# 22557       Brooklyn     Apartment                         NaN
# 22558       Brooklyn     Apartment                         NaN
# 22568       Brooklyn     Apartment                         NaN
# 23763         Queens     Apartment                         NaN
# 23857         Queens         House                         NaN
# 23858         Queens         House                         NaN
# 28569      Manhattan     Apartment                       100.0
# 29206       Brooklyn     Apartment                         NaN
# 29207       Brooklyn     Apartment                         NaN
# 29209       Brooklyn     Apartment                        80.0
# 29710          Bronx     Apartment                         NaN
# 29727          Bronx     Apartment                         NaN
#
#              Room Type  Zipcode  Beds  Number of Records  Number Of Reviews  \
# 31         Shared room  10038.0   1.0                  1                  0
# 6313       Shared room  10029.0   1.0                  1                  0
# 8571      Private room  11237.0   1.0                  1                  0
# 21337     Private room  11238.0   1.0                  1                  1
# 21702  Entire home/apt  10014.0   1.0                  1                  0
# 22557     Private room  11220.0   1.0                  1                  0
# 22558     Private room  11220.0   1.0                  1                  0
# 22568     Private room  11220.0   1.0                  1                  0
# 23763     Private room  11385.0   1.0                  1                  0
# 23857     Private room  11692.0   1.0                  1                  0
# 23858     Private room  11692.0   1.0                  1                  0
# 28569     Private room  10025.0   1.0                  1                  1
# 29206      Shared room  11216.0   4.0                  1                  0
# 29207      Shared room  11216.0   4.0                  1                  0
# 29209      Shared room  11216.0   4.0                  1                  1
# 29710     Private room  10457.0   1.0                  1                  0
# 29727      Shared room  10457.0   1.0                  1                  0
#
#       Price  Review Scores Rating
# 31       99                   NaN
# 6313     49                   NaN
# 8571     60                   NaN
# 21337    50                 100.0
# 21702   250                   NaN
# 22557    35                   NaN
# 22558    35                   NaN
# 22568    80                   NaN
# 23763    45                   NaN
# 23857    65                   NaN
# 23858    65                   NaN
# 28569    89                 100.0
# 29206    30                   NaN
# 29207    30                   NaN
# 29209    30                  80.0
# 29710    60                   NaN
# 29727    40                   NaN

# %%
df.count()      # Used to count the number of rows
# Out:
# Host Id                       30473
# Host Since                    30470
# Name                          30473
# Neighbourhood                 30473
# Property Type                 30470
# Review Scores Rating (bin)    22152
# Room Type                     30473
# Zipcode                       30339
# Beds                          30388
# Number of Records             30473
# Number Of Reviews             30473
# Price                         30473
# Review Scores Rating          22152
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#     Host Id  Host Since                                Name Neighbourhood   \
# 0   5162530         NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899         NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626         NaN                Sunny Room in Harlem      Manhattan
# 3       500  26/06/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  26/06/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
#    Number of Records  Number Of Reviews Price  Review Scores Rating
# 0                  1                  0   145                   NaN
# 1                  1                  1    37                   NaN
# 2                  1                  1    28                   NaN
# 3                  1                  0   199                   NaN
# 4                  1                 39   549                  96.0

# %%
df.count()
# Out:
# Host Id                       30456
# Host Since                    30453
# Name                          30456
# Neighbourhood                 30456
# Property Type                 30453
# Review Scores Rating (bin)    22149
# Room Type                     30456
# Zipcode                       30322
# Beds                          30371
# Number of Records             30456
# Number Of Reviews             30456
# Price                         30456
# Review Scores Rating          22149
# dtype: int64

# %%
#Dropping the missing or null values.
print(df.isnull().sum())
# Out:
# Host Id                          0
# Host Since                       3
# Name                             0
# Neighbourhood                    0
# Property Type                    3
# Review Scores Rating (bin)    8307
# Room Type                        0
# Zipcode                        134
# Beds                            85
# Number of Records                0
# Number Of Reviews                0
# Price                            0
# Review Scores Rating          8307
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# Host Id                       22004
# Host Since                    22004
# Name                          22004
# Neighbourhood                 22004
# Property Type                 22004
# Review Scores Rating (bin)    22004
# Room Type                     22004
# Zipcode                       22004
# Beds                          22004
# Number of Records             22004
# Number Of Reviews             22004
# Price                         22004
# Review Scores Rating          22004
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Host Id                       0
# Host Since                    0
# Name                          0
# Neighbourhood                 0
# Property Type                 0
# Review Scores Rating (bin)    0
# Room Type                     0
# Zipcode                       0
# Beds                          0
# Number of Records             0
# Number Of Reviews             0
# Price                         0
# Review Scores Rating          0
# dtype: int64

# %%
df.head(2)
# Out:
#    Host Id  Host Since                                Name Neighbourhood   \
# 4      500  26/06/2008            Trendy Times Square Loft      Manhattan
# 5     1039  25/07/2008  Big Greenpoint 1BD w/ Skyline View       Brooklyn
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 4     Apartment                        95.0     Private room  10036.0   3.0
# 5     Apartment                       100.0  Entire home/apt  11222.0   1.0
#
#    Number of Records  Number Of Reviews Price  Review Scores Rating
# 4                  1                 39   549                  96.0
# 5                  1                  4   149                 100.0

# %%
# Save csv

filepath = Path('data/data_airbnb.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  

df.to_csv(filepath, index=False) 
df.head(10)
# Out:
#     Host Id  Host Since                                 Name Neighbourhood   \
# 4       500  26/06/2008             Trendy Times Square Loft      Manhattan
# 5      1039  25/07/2008   Big Greenpoint 1BD w/ Skyline View       Brooklyn
# 6      1783  12/08/2008                         Amazing Also      Manhattan
# 7      2078  15/08/2008  Colorful, quiet, & near the subway!       Brooklyn
# 8      2339  20/08/2008  East Village Cocoon: 2 Bedroom Flat      Manhattan
# 9      2339  20/08/2008   Lovely 2 Bedroom East Village Nest      Manhattan
# 10     2571  27/08/2008                           THE PUTNAM       Brooklyn
# 11     2758  06/09/2008     Stay at Chez Chic budget room #1      Manhattan
# 12     2758  06/09/2008     Stay at Chez Chic budget Room #2      Manhattan
# 14     2845  09/09/2008                       Midtown Castle      Manhattan
#
#    Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 4      Apartment                        95.0     Private room  10036.0   3.0
# 5      Apartment                       100.0  Entire home/apt  11222.0   1.0
# 6      Apartment                       100.0  Entire home/apt  10004.0   1.0
# 7      Apartment                        90.0     Private room  11201.0   1.0
# 8      Apartment                        90.0  Entire home/apt  10009.0   2.0
# 9      Apartment                        95.0  Entire home/apt  10009.0   2.0
# 10     Apartment                        95.0  Entire home/apt  11221.0   2.0
# 11     Apartment                        90.0     Private room  10026.0   2.0
# 12     Apartment                        90.0     Private room  10026.0   2.0
# 14     Apartment                        95.0  Entire home/apt  10018.0   1.0
#
#     Number of Records  Number Of Reviews Price  Review Scores Rating
# 4                   1                 39   549                  96.0
# 5                   1                  4   149                 100.0
# 6                   1                  9   250                 100.0
# 7                   1                 80    90                  94.0
# 8                   1                 95   270                  90.0
# 9                   1                 23   290                  96.0
# 10                  1                 14   170                  98.0
# 11                  1                120    59                  93.0
# 12                  1                 81    49                  91.0
# 14                  1                 17   285                  97.0
